# %% [markdown]
# # EDA

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# THE EDA WILL NOT SAVE ANY DATASET. IT WILL ONLY READ THE INITIAL DATASET AND EXPLORE IT AND THEN WE WILL DIRECTLY READ THE FINAL_DATASET TO EXPLORE IT ALSO...

# %%
df = pd.read_csv("..//data//dataset.csv")
df
# Out:
#               utc_timestamp  DE_wind_generation_actual  DE_wind_capacity  \
# 0      2015-01-01T00:00:00Z                     8852.0           27913.0
# 1      2015-01-01T01:00:00Z                     9054.0           27913.0
# 2      2015-01-01T02:00:00Z                     9070.0           27913.0
# 3      2015-01-01T03:00:00Z                     9163.0           27913.0
# 4      2015-01-01T04:00:00Z                     9231.0           27913.0
# ...                     ...                        ...               ...
# 50395  2020-09-30T19:00:00Z                    10654.0               NaN
# 50396  2020-09-30T20:00:00Z                    11836.0               NaN
# 50397  2020-09-30T21:00:00Z                    12168.0               NaN
# 50398  2020-09-30T22:00:00Z                    12533.0               NaN
# 50399  2020-09-30T23:00:00Z                    12798.0               NaN
#
#        DE_wind_offshore_capacity  DE_wind_onshore_capacity  DE_wind_profile  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50400 entries, 0 to 50399
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   utc_timestamp              50400 non-null  object
#  1   DE_wind_generation_actual  50326 non-null  float64
#  2   DE_wind_capacity           43799 non-null  float64
#  3   DE_wind_offshore_capacity  43799 non-null  float64
#  4   DE_wind_onshore_capacity   43799 non-null  float64
#  5   DE_wind_profile            43725 non-null  float64
#  6   DE_wind_offshore_profile   43725 non-null  float64
#  7   DE_wind_onshore_profile    43727 non-null  float64
#  8   DE_wind_speed              50400 non-null  float64
#  9   DE_temperature             50400 non-null  float64
#  10  DE_air_density             50400 non-null  float64
# dtypes: float64(10), object(1)
# memory usage: 4.2+ MB

# %% [markdown]
# ## the dataset was already curated in the file initial.py - we got all the fields needed

# %%
columns = list(df.columns.values)
columns
# Out:
# ['utc_timestamp',
#  'DE_wind_generation_actual',
#  'DE_wind_capacity',
#  'DE_wind_offshore_capacity',
#  'DE_wind_onshore_capacity',
#  'DE_wind_profile',
#  'DE_wind_offshore_profile',
#  'DE_wind_onshore_profile',
#  'DE_wind_speed',
#  'DE_temperature',
#  'DE_air_density']

# %%
plt.figure(figsize=(12,12))
sns.heatmap(df.select_dtypes(include=['number']).corr(), annot=True, cmap="coolwarm")
plt.title("Heatmap - corellations")
# Out:
# Text(0.5, 1.0, 'Heatmap - corellations')

# %% [markdown]
# we might need to drop more

# %%
# plt.figure(figsize=(16,16))
# for i,col in enumerate(columns):
#     plt.subplot(4,4,i+1)
#     sns.histplot(df,x = col,kde=True)

# %%
df
# Out:
#               utc_timestamp  DE_wind_generation_actual  DE_wind_capacity  \
# 0      2015-01-01T00:00:00Z                     8852.0           27913.0
# 1      2015-01-01T01:00:00Z                     9054.0           27913.0
# 2      2015-01-01T02:00:00Z                     9070.0           27913.0
# 3      2015-01-01T03:00:00Z                     9163.0           27913.0
# 4      2015-01-01T04:00:00Z                     9231.0           27913.0
# ...                     ...                        ...               ...
# 50395  2020-09-30T19:00:00Z                    10654.0               NaN
# 50396  2020-09-30T20:00:00Z                    11836.0               NaN
# 50397  2020-09-30T21:00:00Z                    12168.0               NaN
# 50398  2020-09-30T22:00:00Z                    12533.0               NaN
# 50399  2020-09-30T23:00:00Z                    12798.0               NaN
#
#        DE_wind_offshore_capacity  DE_wind_onshore_capacity  DE_wind_profile  \
# ...

# %%
df = df.drop(columns=['DE_wind_offshore_capacity', "DE_wind_onshore_capacity","DE_wind_onshore_profile","DE_wind_offshore_profile","DE_wind_profile"])

# %%
plt.figure(figsize=(8, 8))
sns.heatmap(df.select_dtypes(include=['number']).corr(), annot=True, cmap="coolwarm")

# Title formatting
plt.title("Correlation Heatmap", fontsize=16)

# Rotate x-axis labels for readability
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.yticks(rotation=0, fontsize=10)

# Adjust layout to prevent label cutoff
plt.tight_layout()

# Save with high resolution and proper bounding
plt.savefig("correlation_heatmap.png", dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# wind speed prea correlat ??

# %%
df
# Out:
#               utc_timestamp  DE_wind_generation_actual  DE_wind_capacity  \
# 0      2015-01-01T00:00:00Z                     8852.0           27913.0
# 1      2015-01-01T01:00:00Z                     9054.0           27913.0
# 2      2015-01-01T02:00:00Z                     9070.0           27913.0
# 3      2015-01-01T03:00:00Z                     9163.0           27913.0
# 4      2015-01-01T04:00:00Z                     9231.0           27913.0
# ...                     ...                        ...               ...
# 50395  2020-09-30T19:00:00Z                    10654.0               NaN
# 50396  2020-09-30T20:00:00Z                    11836.0               NaN
# 50397  2020-09-30T21:00:00Z                    12168.0               NaN
# 50398  2020-09-30T22:00:00Z                    12533.0               NaN
# 50399  2020-09-30T23:00:00Z                    12798.0               NaN
#
#        DE_wind_speed  DE_temperature  DE_air_density
# ...

# %%
df.to_csv("good_dataset1.csv", index=False)

# %%
columns = list(df.columns.values)
columns.remove("utc_timestamp")
columns
# Out:
# ['DE_wind_generation_actual',
#  'DE_wind_capacity',
#  'DE_wind_speed',
#  'DE_temperature',
#  'DE_air_density']

# %%
plt.figure(figsize=(16,16))
for i, col in enumerate(columns):
    plt.subplot(4, 3, i+1)
    sns.histplot(df, x=col, kde=True)
    plt.title(f"Distribution of {col}")
plt.tight_layout()

# %%
plt.figure(figsize=(16,16))
for i, col in enumerate(columns):
    plt.subplot(4, 3, i+1)
    sns.boxplot(x=df[col])
    plt.title(f"Boxplot of {col}")

plt.tight_layout()
plt.show()

# %%
df['DE_wind_speed'].skew()
# Out:
# np.float64(1.1637678982573298)
